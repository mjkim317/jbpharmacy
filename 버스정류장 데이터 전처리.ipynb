# %% [markdown]
# ## 2022년_전국버스정류장 위치정보_데이터

# %%
import pandas as pd
import geopandas
import numpy as np

# %% [markdown]
# ## 버스 정류소

# %%
bus = pd.read_csv("C:/Users/user/Desktop/mjpharm/data/2022년_전국버스정류장 위치정보_데이터.csv")
bus
# Out:
#                정류장번호       정류장명         위도          경도          정보수집일시  \
# 0       ASB214010001    석근2리 입구  36.935731  127.043094  20221012050123
# 1       ASB214015410    석근2리 입구  36.935633  127.043204  20221012050123
# 2       ASB214015456       오성슈퍼  36.951671  127.052784  20221012050123
# 3       ASB214015459     팽성초교입구  36.952036  127.053031  20221012050123
# 4       ASB214015461      대사리입구  36.944598  127.053092  20221012050123
# ...              ...        ...        ...         ...             ...
# 196004       YSB9505  (가상)남양산TG  35.324320  129.026500  20221012045507
# 196005       YSB9506   (가상)양산JC  35.329890  129.032600  20221012045507
# 196006       YSB9507   (가상)구서JC  35.253500  129.100100  20221012045507
# 196007       YSB9508   (가상)창기마을  35.336660  129.123300  20221012045507
# 196008       YSB9509   (가상)임기마을  35.322350  129.115700  20221012045507
#
#         모바일단축번호   도시코드  도시명 관리도시명
# 0       10001.0  34040  아산시    아산
# 1       15410.0  34040  아산시    아산
# ...

# %%
bus2 = bus.astype({'도시코드' : 'str'})
jb_bus = bus[bus['도시코드'].str.startswith('35')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 bus2 = bus.astype({'도시코드' : 'str'})
# ----> 2 jb_bus = bus[bus['도시코드'].str.startswith('35')]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
jb_bus

# %%
jb_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/jbbus.csv")

# %%
jeonju_bus = jb_bus[jb_bus["도시명"].str.startswith('전주시')]
gunsan_bus = jb_bus[jb_bus["도시명"].str.startswith('군산시')]
gochang_bus = jb_bus[jb_bus["도시명"].str.startswith('고창군')]
gimje_bus = jb_bus[jb_bus["도시명"].str.startswith('김제시')]
namwon_bus = jb_bus[jb_bus["도시명"].str.startswith('남원시')]
muju_bus = jb_bus[jb_bus["도시명"].str.startswith('무주군')]
buan_bus = jb_bus[jb_bus["도시명"].str.startswith('부안군')]
sunchang_bus = jb_bus[jb_bus["도시명"].str.startswith('순창군')]
wanju_bus = jb_bus[jb_bus["도시명"].str.startswith('완주군')]
iksan_bus = jb_bus[jb_bus["도시명"].str.startswith('익산시')]
imsil_bus = jb_bus[jb_bus["도시명"].str.startswith('임실군')]
jangsu_bus = jb_bus[jb_bus["도시명"].str.startswith('장수군')]
jeongeup_bus = jb_bus[jb_bus["도시명"].str.startswith('정읍시')]
jinan_bus = jb_bus[jb_bus["도시명"].str.startswith('진안군')]

# %%
jeonju_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/jeonju_bus.csv")
gunsan_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/gunsan_bus.csv")
gochang_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/gochang_bus.csv")
gimje_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/gimje_bus.csv")
namwon_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/namwon_bus.csv")
muju_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/muju_bus.csv")
buan_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/buan_bus.csv")
sunchang_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/sunchang_bus.csv")
wanju_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/wanju_bus.csv")
iksan_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/iksan_bus.csv")
imsil_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/imsil_bus.csv")
jangsu_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/jangsu_bus.csv")
jeongeup_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/jeongeup_bus.csv")
jinan_bus.to_csv("C:/Users/user/Desktop/mjpharm/data/jinan_bus.csv")

# %% [markdown]
# ## 학교

# %%
school = pd.read_csv("C:/Users/user/Desktop/mjpharm/data/전국초중등학교위치표준데이터.csv", encoding='cp949')
school
# Out:
#              학교ID          학교명 학교급구분        설립일자 설립형태 본교분교구분 운영상태  \
# 0      B000004204       한울초등학교  초등학교  2008-09-01   공립     본교   운영
# 1      B000011476  수원농생명과학고등학교  고등학교  1936-07-01   공립     본교   운영
# 2      B000009647        녹양중학교   중학교  2008-03-01   공립     본교   운영
# 3      B000005955       초락초등학교  초등학교  1959-04-02   공립     본교   운영
# 4      B000005385       상봉초등학교  초등학교  1946-09-01   공립     본교   운영
# ...           ...          ...   ...         ...  ...    ...  ...
# 11983  B000003371     대전옥계초등학교  초등학교  1982-12-09   공립     본교   운영
# 11984  B000003345       성덕초등학교  초등학교  2011-03-11   공립     본교   운영
# 11985  B000005441       이월초등학교  초등학교  1920-04-01   공립     본교   운영
# 11986  B000009875        해안중학교   중학교  1979-03-08   공립     본교   운영
# 11987  B000011237        초계중학교   중학교  1952-06-01   공립     본교   운영
#
#                           소재지지번주소                                    소재지도로명주소  \
# 0             경기도 화성시 향남읍 행정리 442        경기도 화성시 향남읍 행정중앙1로 25 . 한울초등학교 (향남읍)
# ...

# %%
#전라북도교육청코드: 832000
#school2 = school.astype({'교육지원청코드' : 'str'})
jb_school = school[school['시도교육청코드']==8320000]

jb_school
# Out:
#              학교ID       학교명 학교급구분        설립일자 설립형태 본교분교구분 운영상태  \
# 5      B000006182  남원도통초등학교  초등학교  2002-03-01   공립     본교   운영
# 57     B000006224    백구초등학교  초등학교  1963-11-22   공립     본교   운영
# 65     B000011640    세인고등학교  고등학교  1999-03-01   사립     본교   운영
# 78     B000006085  이리동산초등학교  초등학교  1941-04-10   공립     본교   운영
# 100    B000006332    동산초등학교  초등학교  1963-03-07   공립     본교   운영
# ...           ...       ...   ...         ...  ...    ...  ...
# 11684  B000030580   전주만성중학교   중학교  2022-03-01   공립     본교   운영
# 11758  B000011624  전주공업고등학교  고등학교  1916-05-01   공립     본교   운영
# 11865  B000006161    도학초등학교  초등학교  1957-09-03   공립     본교   운영
# 11890  B000026523  전주효천초등학교  초등학교  2020-03-01   공립     본교   운영
# 11902  B000026521  전주양현초등학교  초등학교  2019-03-01   공립     본교   운영
#
#                        소재지지번주소                                     소재지도로명주소  \
# 5             전라북도 남원시 도통동 613             전라북도 남원시 대교2길 22 (도통동. 남원도통초등학교)
# ...

# %%
jb_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jbschool.csv")

# %%
school_reverse = pd.read_csv("C:/Users/user/Desktop/mjpharm/data/jbschool_reverse2.csv", encoding='cp949')

jeonju_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 전주시')]
gunsan_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 군산시')]
gochang_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 고창군')]
gimje_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 김제시')]
namwon_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 남원시')]
muju_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 무주군')]
buan_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 부안군')]
sunchang_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 순창군')]
wanju_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 완주군')]
iksan_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 익산시')]
imsil_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 임실군')]
jangsu_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 장수군')]
jeongeup_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 정읍시')]
jinan_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 진안군')]

# %%
jeonju_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 전주시')]
jeonju_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_school/jeonju_school.csv")

gunsan_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 군산시')]
gunsan_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_school/gunsan_school.csv")

gochang_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 고창군')]
gochang_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_school/gochang_school.csv")

gimje_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 김제시')]
gimje_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_school/gimje_school.csv")

namwon_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 남원시')]
namwon_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_school/namwon_school.csv")

muju_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 무주군')]
muju_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_school/muju_school.csv")

buan_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 부안군')]
buan_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_school/buan_school.csv")

sunchang_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 순창군')]
sunchang_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_school/sunchang_school.csv")

wanju_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 완주군')]
wanju_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_school/wanju_school.csv")

iksan_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 익산시')]
iksan_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_school/iksan_school.csv")

imsil_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 임실군')]
imsil_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_school/imsil_school.csv")

jangsu_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 장수군')]
jangsu_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_school/jangsu_school.csv")

jeongeup_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 정읍시')]
jeongeup_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_school/jeongeup_school.csv")

jinan_school = school_reverse[school_reverse["_ROAD_AD"].str.startswith('전라북도 진안군')]
jinan_school.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_school/jinan_school.csv")

# %% [markdown]
# ## 약국

# %%
phar = pd.read_csv("C:/Users/user/Desktop/mjpharm/data/pharmacy.csv", encoding='cp949')
phar
# Out:
#         사업장명                                  도로명주소   Latitude   Longitude  \
# 0      프라임약국   전라북도 전주시 덕진구 만성로 140, 107,108호 (만성동)  35.843478  127.077060
# 1    센타프라자약국  전라북도 전주시 덕진구 만성중앙로 45, 109,110호 (만성동)  35.843107  127.076840
# 2    에코유익한약국     전라북도 전주시 덕진구 세병로 172, 103호 (송천동2가)  35.878564  127.133600
# 3    리더스종합약국         전라북도 전주시 완산구 온고을로 62, 1층 (서신동)  35.834224  127.116179
# 4       다솜약국           전라북도 전주시 완산구 우전로 250 (효자동2가)  35.817160  127.102276
# ..       ...                                    ...        ...         ...
# 946  부안신세계약국                   전라북도 부안군 부안읍 석정로 224  35.725702  126.737032
# 947   줄포종합약국          전라북도 부안군 줄포면 줄포중앙로 50, 줄포종합약국  35.590213  126.678857
# 948     부안약국                 전라북도 부안군 부안읍 시장1길 5-31  35.727055  126.736103
# 949      수약국                 전라북도 부안군 부안읍 시장1길 5-30  35.726748  126.734634
# 950      박약국                    전라북도 부안군 부안읍 동중길 31  35.729843  126.735012
#
#                     _PARCEL_AD                    _ROAD_AD
# ...

# %%
jeonju_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 전주시')]
jeonju_phar.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_phar/jeonju_phar.csv")

gunsan_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 군산시')]
gunsan_phar.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_phar/gunsan_phar.csv")

gochang_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 고창군')]
gochang_phar.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_phar/gochang_phar.csv")

gimje_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 김제시')]
gimje_phar.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_phar/gimje_phar.csv")

namwon_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 남원시')]
namwon_phar.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_phar/namwon_phar.csv")

muju_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 무주군')]
muju_phar.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_phar/muju_phar.csv")

buan_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 부안군')]
buan_phar.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_phar/buan_phar.csv")

sunchang_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 순창군')]
sunchang_phar.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_phar/sunchang_phar.csv")

wanju_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 완주군')]
wanju_phar.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_phar/wanju_phar.csv")

iksan_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 익산시')]
iksan_phar.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_phar/iksan_phar.csv")

imsil_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 임실군')]
imsil_phar.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_phar/imsil_phar.csv")

jangsu_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 장수군')]
jangsu_phar.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_phar/jangsu_phar.csv")

jeongeup_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 정읍시')]
jeongeup_phar.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_phar/jeongeup_phar.csv")

jinan_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 진안군')]
jinan_phar.to_csv("C:/Users/user/Desktop/mjpharm/data/jb_phar/jinan_phar.csv")

# %%
muju_phar = phar[phar["_ROAD_AD"].str.startswith('전라북도 무주군')]
muju_phar
# Out:
# Empty DataFrame
# Columns: [사업장명, 도로명주소, Latitude, Longitude, _PARCEL_AD, _ROAD_AD]
# Index: []
